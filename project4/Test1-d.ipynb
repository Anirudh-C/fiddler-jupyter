# %%
# %matplotlib inline
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from matplotlib import animation
matplotlib.rc('animation', html='html5')
from ipywidgets import interact, interactive, widgets
from IPython.display import display, clear_output

# %%
# Global Constants
d = (0,1)
N = 40
dx = (d[1] - d[0])/(N-1)
x = np.linspace(d[0],d[1],N)

# %%
def updateExplicitSolution(f,lamb,n):
    """
    This method takes f, lambda and number of time
    intervals n to return the state of the solution after n time intervals
    """
    U_prev = np.zeros(N)
    U_next = np.zeros(N)
    for i in range(n):
        U_prev[:] = U_next
        for j in range(1,N-1):
            U_next[j] = lamb*U_prev[j-1] + (1-2*lamb)*U_prev[j] + lamb*U_prev[j+1] + lamb*dx*dx*f[j]
    return U_next

# %% [markdown]
# # Test Case 1
# $$f = 1$$

# %% [markdown]
# $$\lambda = 0.25$$

# %%
lamb = 0.25

f = np.ones(N)
g = lambda x: x/2-x*x/2
vfunc = np.vectorize(g)
uexact = vfunc(x)
ran = (0,0.15)
maxframes = 1500
fig, ax = plt.subplots()
xdata = np.linspace(d[0],d[1],N)
ydata = np.zeros(N)
line1, = plt.plot([],[],'r',animated=True,label="Numerical")
line2, = ax.plot(x,uexact,'b',label="Exact")
ax.set_xlabel('x')
ax.set_ylabel('U')
plt.legend()
plt.grid(True)
plt.draw()
fr = range(0,maxframes,8)
def init():
    ax.set_xlim(0,1)
    ax.set_ylim(ran[0],ran[1])
    line1.set_data(xdata,ydata)
    plt.rcParams.update({'font.size':14})
    return line1,
def update(frame):
    line1.set_ydata(updateExplicitSolution(f,lamb,frame))
    return line1,
anim = animation.FuncAnimation(fig,update,frames=fr,init_func=init,blit=True,interval = 30)
plt.close()
anim
# Out:
# <video width="432" height="288" controls autoplay loop>
#   <source type="video/mp4" src="...

# %% [markdown]
# $$\lambda = 0.5$$

# %%
lamb = 0.5

f = np.ones(N)
g = lambda x: x/2-x*x/2
vfunc = np.vectorize(g)
uexact = vfunc(x)
ran = (0,0.15)
maxframes = 1500
fig, ax = plt.subplots()
xdata = np.linspace(d[0],d[1],N)
ydata = np.zeros(N)
line1, = plt.plot([],[],'r',animated=True,label="Numerical")
line2, = ax.plot(x,uexact,'b',label="Exact")
ax.set_xlabel('x')
ax.set_ylabel('U')
plt.legend()
plt.grid(True)
plt.draw()
fr = range(0,maxframes,8)
def init():
    ax.set_xlim(0,1)
    ax.set_ylim(ran[0],ran[1])
    line1.set_data(xdata,ydata)
    plt.rcParams.update({'font.size':14})
    return line1,
def update(frame):
    line1.set_ydata(updateExplicitSolution(f,lamb,frame))
    return line1,
anim = animation.FuncAnimation(fig,update,frames=fr,init_func=init,blit=True,interval = 30)
plt.close()
anim
# Out:
# <video width="432" height="288" controls autoplay loop>
#   <source type="video/mp4" src="...

# %% [markdown]
# $$\lambda = 0.75$$

# %%
lamb = 0.75

f = np.ones(N)
g = lambda x: x/2-x*x/2
vfunc = np.vectorize(g)
uexact = vfunc(x)
ran = (0,0.15)
maxframes = 1500
fig, ax = plt.subplots()
xdata = np.linspace(d[0],d[1],N)
ydata = np.zeros(N)
line1, = plt.plot([],[],'r',animated=True,label="Numerical")
line2, = ax.plot(x,uexact,'b',label="Exact")
ax.set_xlabel('x')
ax.set_ylabel('U')
plt.legend()
plt.grid(True)
plt.draw()
fr = range(0,maxframes,8)
def init():
    ax.set_xlim(0,1)
    ax.set_ylim(ran[0],ran[1])
    line1.set_data(xdata,ydata)
    plt.rcParams.update({'font.size':14})
    return line1,
def update(frame):
    line1.set_ydata(updateExplicitSolution(f,lamb,frame))
    return line1,
anim = animation.FuncAnimation(fig,update,frames=fr,init_func=init,blit=True,interval = 30)
plt.close()
anim
# Out:
# /home/anirudh/.local/lib/python3.6/site-packages/ipykernel_launcher.py:11: RuntimeWarning: overflow encountered in double_scalars
#   # This is added back by InteractiveShellApp.init_path()
# /home/anirudh/.local/lib/python3.6/site-packages/ipykernel_launcher.py:11: RuntimeWarning: invalid value encountered in double_scalars
#   # This is added back by InteractiveShellApp.init_path()
# <video width="432" height="288" controls autoplay loop>
#   <source type="video/mp4" src="...

# %% [markdown]
# # Test Case 2
# $$f = sin(2 \pi x)$$

# %%
lamb = 0.25

f = np.sin(2*np.pi*x)
uexact = (1/(4*np.pi**2))*np.sin(2*np.pi*x)
ran = (-0.04,0.04)
maxframes = 800
fig, ax = plt.subplots()
xdata = np.linspace(d[0],d[1],N)
ydata = np.zeros(N)
line1, = plt.plot([],[],'r',animated=True,label="Numerical")
line2, = ax.plot(x,uexact,'b',label="Exact")
ax.set_xlabel('x')
ax.set_ylabel('U')
plt.legend()
plt.grid(True)
plt.draw()
fr = range(0,maxframes,8)
def init():
    ax.set_xlim(0,1)
    ax.set_ylim(ran[0],ran[1])
    line1.set_data(xdata,ydata)
    plt.rcParams.update({'font.size':14})
    return line1,
def update(frame):
    line1.set_ydata(updateExplicitSolution(f,lamb,frame))
    return line1,
anim = animation.FuncAnimation(fig,update,frames=fr,init_func=init,blit=True,interval = 30)
plt.close()
anim
# Out:
# <video width="432" height="288" controls autoplay loop>
#   <source type="video/mp4" src="...

# %% [markdown]
# $$\lambda = 0.5$$

# %%
lamb = 0.5

f = np.sin(2*np.pi*x)
uexact = (1/(4*np.pi**2))*np.sin(2*np.pi*x)
ran = (-0.04,0.04)
maxframes = 800
fig, ax = plt.subplots()
xdata = np.linspace(d[0],d[1],N)
ydata = np.zeros(N)
line1, = plt.plot([],[],'r',animated=True,label="Numerical")
line2, = ax.plot(x,uexact,'b',label="Exact")
ax.set_xlabel('x')
ax.set_ylabel('U')
plt.legend()
plt.grid(True)
plt.draw()
fr = range(0,maxframes,8)
def init():
    ax.set_xlim(0,1)
    ax.set_ylim(ran[0],ran[1])
    line1.set_data(xdata,ydata)
    plt.rcParams.update({'font.size':14})
    return line1,
def update(frame):
    line1.set_ydata(updateExplicitSolution(f,lamb,frame))
    return line1,
anim = animation.FuncAnimation(fig,update,frames=fr,init_func=init,blit=True,interval = 30)
plt.close()
anim
# Out:
# <video width="432" height="288" controls autoplay loop>
#   <source type="video/mp4" src="...

# %% [markdown]
# $$\lambda = 0.75$$

# %%
lamb = 0.75

f = np.sin(2*np.pi*x)
uexact = (1/(4*np.pi**2))*np.sin(2*np.pi*x)
ran = (-0.04,0.04)
maxframes = 800
fig, ax = plt.subplots()
xdata = np.linspace(d[0],d[1],N)
ydata = np.zeros(N)
line1, = plt.plot([],[],'r',animated=True,label="Numerical")
line2, = ax.plot(x,uexact,'b',label="Exact")
ax.set_xlabel('x')
ax.set_ylabel('U')
plt.legend()
plt.grid(True)
plt.draw()
fr = range(0,maxframes,8)
def init():
    ax.set_xlim(0,1)
    ax.set_ylim(ran[0],ran[1])
    line1.set_data(xdata,ydata)
    plt.rcParams.update({'font.size':14})
    return line1,
def update(frame):
    line1.set_ydata(updateExplicitSolution(f,lamb,frame))
    return line1,
anim = animation.FuncAnimation(fig,update,frames=fr,init_func=init,blit=True,interval = 30)
plt.close()
anim
# Out:
# <video width="432" height="288" controls autoplay loop>
#   <source type="video/mp4" src="...
